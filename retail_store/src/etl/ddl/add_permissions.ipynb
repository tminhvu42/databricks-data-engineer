# %%
dbutils.widgets.text("catalog_name", "")

catalog_name = dbutils.widgets.get("catalog_name")

# %%
spark.sql(f"""
          GRANT ALL PRIVILEGES ON CATALOG {catalog_name} TO `tminhvu42@gmail.com`
          """)

# %%
spark.sql(f"""
          GRANT ALL PRIVILEGES ON CATALOG {catalog_name} TO `2b99d076-2d63-4aa4-940f-2c63d159e26e`
          """)
